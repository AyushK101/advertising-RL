# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.subplot(1,2,1,)
plt.plot([1,2,3], 'd--')
plt.subplot(1,2,2)
plt.scatter([1,2,3],[1,2,3],marker='d')
plt.figure(figsize=(15,5))  
plt.subplot(2,2,1)
plt.plot([1,2,3], 'd')
plt.subplot(2,2,2)
plt.plot([1,2,3] , 'dr--')
plt.show()
